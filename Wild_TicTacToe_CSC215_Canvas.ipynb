# %% [markdown]
# ## Mini-Project 4 (Part II): Solving Wild Tic-Tac-Toe Using Minimax
#
#
# #### CSC 215 Artificial Intelligence (Fall 2020)
#
# #### Dr. Haiquan Chen, California State University, Sacramento

# %%
import random
import time

current = []


def show(board, player):
    print(player, ":\n")
    for i in range(3):
        for j in range(9):
            if j // 3 == i:
                print(" ", board[j], end="  |")
        print()
        print("------------------")


def check_line(char, pos1, pos2, pos3):
    return pos1 == pos2 == pos3 == char


def check_all(board, char):
    if check_line(char, board[0], board[1], board[2]):
        return True
    elif check_line(char, board[3], board[4], board[5]):
        return True
    elif check_line(char, board[6], board[7], board[8]):
        return True
    elif check_line(char, board[0], board[3], board[6]):
        return True
    elif check_line(char, board[1], board[4], board[7]):
        return True
    elif check_line(char, board[2], board[5], board[8]):
        return True
    elif check_line(char, board[0], board[4], board[8]):
        return True
    elif check_line(char, board[2], board[4], board[6]):
        return True
    else:
        return False


def check_draw(board):
    return set(board) == {"o", "x"}


def check_game_over(board, player):
    if check_all(board, "x") or check_all(board, "o"):
        if player == "P1":
            return -10          # this should be -10 not 10
        elif player == "P2":
            return +10           # this should be 10 not -10
    elif check_draw(board):
        return 0
    else: 
        return False


def minimax(board, player,move_num,level, middle):
    global current
    current_score = check_game_over(board, player)
    
    if current_score is not False:
        return current_score
    
    scores = []
    moves = []
    choices=[]
    
    if(player == "P1"):
        next_player = "P2"
    else:
        next_player = "P1"
    
    for j in ["x","o"]:
        for i in range(9):
        # check all possible moves.  

            if board[i] == "x" or board[i] == "o":
                continue
            
            if middle == False:
                if move_num == 0 and i == 4 and level == 0:
                    continue

            new_board = board.copy()
            new_board[i] = j

            current_score = minimax(new_board, next_player, move_num, level+1, middle)
            scores.append(current_score)
            moves.append(i)
            choices.append(j)
            
            if player == "P1":
                if current_score == 10:
                    break
            
            elif player == "P2":
                if current_score == -10:
                    break
            
                
    if player == "P1":
    # Find the move with the highest score.   Add that move to current and return that score. 
    
        cur_score = max(scores)
        temp_var = scores.index(cur_score)
        choice = choices[temp_var]
        index = moves[temp_var] 
    
    elif player == "P2":
    # Find the move with the lowest score.   Add that move to current and return that score.
        
        cur_score = min(scores)
        temp_var = scores.index(cur_score)
        choice = choices[temp_var]
        index = moves[temp_var]
        
        
    board[index] = choice
    current.append(board)
    return cur_score

# %% [markdown]
# ## Optimal vs Optimal

# %%
def optimal_vs_optimal(middle = True):
    global current
    board = [0, 1, 2, 3, 4, 5, 6, 7, 8]
    current = []
    print("Player 1 and Player 2 Both play optimally.\n")
    show(board, "Board")
    curr = ["P1", "P2"]
    
    
    #board[0] = 'x'
    #show(board, "P1")
    #print()
    #i = 1
    
    i = 0
    move_num=0
    while True:
        level=0
        print()
        minimax(board, curr[i],move_num, level, middle)
        show(current[len(current) - 1], curr[i])
        board = current[len(current) - 1]
        print()
        if check_all(board, "x") or check_all(board, "o"):
            print(curr[i] + " Wins!")
            return curr[i]
        elif check_draw(board):
            print("Draw!")
            return "Draw"
        i = (i + 1) % 2
        move_num+=1

#start_time = time.time()
#optimal_vs_optimal()
#print("\nSeconds Elapsed:", time.time() - start_time)

# %%
optimal_vs_optimal(middle = True)
# Out:
# Player 1 and Player 2 Both play optimally.
#
# Board :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P1 :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  x  |
# ------------------
#
# P1 Wins!
# 'P1'

# %%
print("Player P1 and Player P2 Both play optimally and P1 can choose any cell as a first move.\n")
p1_won = 0
p2_won = 0
draw = 0
for i in range(0,20):
    result = optimal_vs_optimal(middle = True)
    if result == "P1":
        p1_won += 1
    elif result == "P2":
        p2_won += 1
    elif result == "Draw":
        draw += 1
    print("Game {} Result : {}".format(i+1,result))

#print("\nP1 won {} game, P2 won {} game and {} game results into Draw.".format(p1_won,p2_won,draw))
# Out:
# Player P1 and Player P2 Both play optimally and P1 can choose any cell as a first move.
#
# Player 1 and Player 2 Both play optimally.
#
# Board :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P1 :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  x  |
# ------------------
#
# P1 Wins!
# Game 1 Result : P1
# Player 1 and Player 2 Both play optimally.
#
# Board :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P1 :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  x  |
# ------------------
#
# P1 Wins!
# Game 2 Result : P1
# Player 1 and Player 2 Both play optimally.
#
# Board :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P1 :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  x  |
# ------------------
#
# P1 Wins!
# Game 3 Result : P1
# Player 1 and Player 2 Both play optimally.
#
# Board :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P1 :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  x  |
# ------------------
#
# P1 Wins!
# Game 4 Result : P1
# Player 1 and Player 2 Both play optimally.
#
# Board :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P1 :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  x  |
# ------------------
#
# P1 Wins!
# Game 5 Result : P1
# Player 1 and Player 2 Both play optimally.
#
# Board :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P1 :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  x  |
# ------------------
#
# P1 Wins!
# Game 6 Result : P1
# Player 1 and Player 2 Both play optimally.
#
# Board :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P1 :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  x  |
# ------------------
#
# P1 Wins!
# Game 7 Result : P1
# Player 1 and Player 2 Both play optimally.
#
# Board :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P1 :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  x  |
# ------------------
#
# P1 Wins!
# Game 8 Result : P1
# Player 1 and Player 2 Both play optimally.
#
# Board :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P1 :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  x  |
# ------------------
#
# P1 Wins!
# Game 9 Result : P1
# Player 1 and Player 2 Both play optimally.
#
# Board :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P1 :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  x  |
# ------------------
#
# P1 Wins!
# Game 10 Result : P1
# Player 1 and Player 2 Both play optimally.
#
# Board :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P1 :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  x  |
# ------------------
#
# P1 Wins!
# Game 11 Result : P1
# Player 1 and Player 2 Both play optimally.
#
# Board :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P1 :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  x  |
# ------------------
#
# P1 Wins!
# Game 12 Result : P1
# Player 1 and Player 2 Both play optimally.
#
# Board :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P1 :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  x  |
# ------------------
#
# P1 Wins!
# Game 13 Result : P1
# Player 1 and Player 2 Both play optimally.
#
# Board :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P1 :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  x  |
# ------------------
#
# P1 Wins!
# Game 14 Result : P1
# Player 1 and Player 2 Both play optimally.
#
# Board :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P1 :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  x  |
# ------------------
#
# P1 Wins!
# Game 15 Result : P1
# Player 1 and Player 2 Both play optimally.
#
# Board :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P1 :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  x  |
# ------------------
#
# P1 Wins!
# Game 16 Result : P1
# Player 1 and Player 2 Both play optimally.
#
# Board :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P1 :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  x  |
# ------------------
#
# P1 Wins!
# Game 17 Result : P1
# Player 1 and Player 2 Both play optimally.
#
# Board :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P1 :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  x  |
# ------------------
#
# P1 Wins!
# Game 18 Result : P1
# Player 1 and Player 2 Both play optimally.
#
# Board :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P1 :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  x  |
# ------------------
#
# P1 Wins!
# Game 19 Result : P1
# Player 1 and Player 2 Both play optimally.
#
# Board :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P1 :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  x  |
# ------------------
#
# P1 Wins!
# Game 20 Result : P1
#
# P1 won 20 game, P2 won 0 game and 0 game results into Draw.

# %%
print ( " P1=OPTIMAL VS P2=OPTIMAL OUTPUT" )
print ( " Games P1 won= {}" .format(p1_won))
print ( " Games P2 won= {}" .format(p2_won))
print ( " Games Drawn= {}" .format(draw))
# Out:
#  P1=OPTIMAL VS P2=OPTIMAL OUTPUT
#  Games P1 won= 20
#  Games P2 won= 0
#  Games Drawn= 0

# %%
optimal_vs_optimal(middle = False)
# Out:
# Player 1 and Player 2 Both play optimally.
#
# Board :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   x  |  x  |  o  |
# ------------------
#
# Draw!
# 'Draw'

# %%
p1_won = 0
p2_won = 0
draw = 0
for i in range(0,20):
    result = optimal_vs_optimal(middle = False)
    if result == "P1":
        p1_won += 1
    elif result == "P2":
        p2_won += 1
    elif result == "Draw":
        draw += 1
    print("Game {} Result : {}".format(i+1,result))
# Out:
# Player 1 and Player 2 Both play optimally.
#
# Board :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   x  |  x  |  o  |
# ------------------
#
# Draw!
# Game 1 Result : Draw
# Player 1 and Player 2 Both play optimally.
#
# Board :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   x  |  x  |  o  |
# ------------------
#
# Draw!
# Game 2 Result : Draw
# Player 1 and Player 2 Both play optimally.
#
# Board :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   x  |  x  |  o  |
# ------------------
#
# Draw!
# Game 3 Result : Draw
# Player 1 and Player 2 Both play optimally.
#
# Board :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   x  |  x  |  o  |
# ------------------
#
# Draw!
# Game 4 Result : Draw
# Player 1 and Player 2 Both play optimally.
#
# Board :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   x  |  x  |  o  |
# ------------------
#
# Draw!
# Game 5 Result : Draw
# Player 1 and Player 2 Both play optimally.
#
# Board :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   x  |  x  |  o  |
# ------------------
#
# Draw!
# Game 6 Result : Draw
# Player 1 and Player 2 Both play optimally.
#
# Board :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   x  |  x  |  o  |
# ------------------
#
# Draw!
# Game 7 Result : Draw
# Player 1 and Player 2 Both play optimally.
#
# Board :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   x  |  x  |  o  |
# ------------------
#
# Draw!
# Game 8 Result : Draw
# Player 1 and Player 2 Both play optimally.
#
# Board :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   x  |  x  |  o  |
# ------------------
#
# Draw!
# Game 9 Result : Draw
# Player 1 and Player 2 Both play optimally.
#
# Board :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   x  |  x  |  o  |
# ------------------
#
# Draw!
# Game 10 Result : Draw
# Player 1 and Player 2 Both play optimally.
#
# Board :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   x  |  x  |  o  |
# ------------------
#
# Draw!
# Game 11 Result : Draw
# Player 1 and Player 2 Both play optimally.
#
# Board :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   x  |  x  |  o  |
# ------------------
#
# Draw!
# Game 12 Result : Draw
# Player 1 and Player 2 Both play optimally.
#
# Board :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   x  |  x  |  o  |
# ------------------
#
# Draw!
# Game 13 Result : Draw
# Player 1 and Player 2 Both play optimally.
#
# Board :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   x  |  x  |  o  |
# ------------------
#
# Draw!
# Game 14 Result : Draw
# Player 1 and Player 2 Both play optimally.
#
# Board :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   x  |  x  |  o  |
# ------------------
#
# Draw!
# Game 15 Result : Draw
# Player 1 and Player 2 Both play optimally.
#
# Board :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   x  |  x  |  o  |
# ------------------
#
# Draw!
# Game 16 Result : Draw
# Player 1 and Player 2 Both play optimally.
#
# Board :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   x  |  x  |  o  |
# ------------------
#
# Draw!
# Game 17 Result : Draw
# Player 1 and Player 2 Both play optimally.
#
# Board :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   x  |  x  |  o  |
# ------------------
#
# Draw!
# Game 18 Result : Draw
# Player 1 and Player 2 Both play optimally.
#
# Board :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   x  |  x  |  o  |
# ------------------
#
# Draw!
# Game 19 Result : Draw
# Player 1 and Player 2 Both play optimally.
#
# Board :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   x  |  x  |  o  |
# ------------------
#
# Draw!
# Game 20 Result : Draw

# %%
print ( " P1=OPTIMAL VS P2=OPTIMAL when middle element is not chosen" )
print ( " Games P1 won= {}" .format(p1_won))
print ( " Games P2 won= {}" .format(p2_won))
print ( " Games Drawn= {}" .format(draw))
# Out:
#  P1=OPTIMAL VS P2=OPTIMAL when middle element is not chosen
#  Games P1 won= 0
#  Games P2 won= 0
#  Games Drawn= 20

# %% [markdown]
# ## Random vs Optimal

# %%
def random_vs_optimal(middle = True):
    global current
    board = [0, 1, 2, 3, 4, 5, 6, 7, 8]
    current = []
    #print("Player 1 plays randomly, and Player 2 plays optimally.\n")
    #show(board, "Board")
    #print()
    curr = ["P1", "P2"]
    i = 0
    move_num = 0
    while True:
        level = 0
        print()
        if curr[i] == "P1":
            valid_choice = [i for i in range(9) if board[i] != "x" and board[i] != "o"]
            ran = valid_choice[int(random.random() * len(valid_choice))]
            ran2 = int(random.random() * 2)
            if ran2 == 0:
                board[ran] = "x"
            elif ran2 == 1:
                board[ran] = "o"
            show(board, "P1")
        elif curr[i] == "P2":
            minimax(board, "P2",move_num,level, middle )
            show(current[len(current) - 1], "P2")
            board = current[len(current) - 1]
        print()
        if check_all(board, "x") or check_all(board, "o"):
            print(curr[i] + " Wins!")
            return curr[i]
        elif check_draw(board):
            print("Draw!")
            return "Draw"
        i = (i + 1) % 2
        move_num += 1


#start_time = time.time()
#random_vs_optimal()
#print("\nSeconds Elapsed:", time.time() - start_time)

# %%
random_vs_optimal(middle = True)
# Out:
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   6  |  x  |  x  |
# ------------------
#
# P2 Wins!
# 'P2'

# %%
p1_won = 0
p2_won = 0
draw = 0
for i in range(0,20):
    result = random_vs_optimal()
    if result == "P1":
        p1_won += 1
    elif result == "P2":
        p2_won += 1
    elif result == "Draw":
        draw += 1
    print("Game {} Result : {}".format(i+1,result))

#print("\nP1 won {} game, P2 won {} game and {} game results into Draw.".format(p1_won,p2_won,draw))
# Out:
# P1 :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  x  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   x  |  x  |  x  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P2 Wins!
# Game 1 Result : P2
#
# P1 :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   x  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   0  |  x  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   x  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   0  |  x  |  o  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   x  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   0  |  x  |  o  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   x  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   0  |  x  |  o  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   x  |  o  |  8  |
# ------------------
#
#
# P2 :
#
#   0  |  x  |  o  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   x  |  o  |  x  |
# ------------------
#
#
# P1 :
#
#   0  |  x  |  o  |
# ------------------
#   x  |  4  |  x  |
# ------------------
#   x  |  o  |  x  |
# ------------------
#
#
# P2 :
#
#   x  |  x  |  o  |
# ------------------
#   x  |  4  |  x  |
# ------------------
#   x  |  o  |  x  |
# ------------------
#
# P2 Wins!
# Game 2 Result : P2
#
# P1 :
#
#   0  |  x  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   0  |  x  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   x  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   0  |  x  |  x  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   x  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  x  |  x  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   x  |  7  |  8  |
# ------------------
#
# P2 Wins!
# Game 3 Result : P2
#
# P1 :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  x  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  x  |  x  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
# P2 Wins!
# Game 4 Result : P2
#
# P1 :
#
#   0  |  1  |  o  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  o  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  o  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  o  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  o  |
# ------------------
#   3  |  4  |  o  |
# ------------------
#   6  |  7  |  o  |
# ------------------
#
# P2 Wins!
# Game 5 Result : P2
#
# P1 :
#
#   0  |  1  |  2  |
# ------------------
#   x  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   0  |  1  |  x  |
# ------------------
#   x  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   0  |  1  |  x  |
# ------------------
#   x  |  4  |  5  |
# ------------------
#   6  |  7  |  o  |
# ------------------
#
#
# P2 :
#
#   0  |  1  |  x  |
# ------------------
#   x  |  4  |  5  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
#
# P1 :
#
#   0  |  1  |  x  |
# ------------------
#   x  |  o  |  5  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
#
# P2 :
#
#   o  |  1  |  x  |
# ------------------
#   x  |  o  |  5  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
# P2 Wins!
# Game 6 Result : P2
#
# P1 :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   x  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  x  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   x  |  7  |  8  |
# ------------------
#
# P2 Wins!
# Game 7 Result : P2
#
# P1 :
#
#   0  |  1  |  o  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  o  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  o  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   o  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  o  |
# ------------------
#   3  |  o  |  5  |
# ------------------
#   o  |  7  |  8  |
# ------------------
#
# P2 Wins!
# Game 8 Result : P2
#
# P1 :
#
#   0  |  o  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  2  |
# ------------------
#   o  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  x  |
# ------------------
#   o  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  x  |
# ------------------
#   o  |  4  |  5  |
# ------------------
#   6  |  7  |  o  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  x  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  7  |  o  |
# ------------------
#
#
# P1 :
#
#   x  |  o  |  x  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  o  |  o  |
# ------------------
#
#
# P2 :
#
#   x  |  o  |  x  |
# ------------------
#   o  |  o  |  x  |
# ------------------
#   6  |  o  |  o  |
# ------------------
#
# P2 Wins!
# Game 9 Result : P2
#
# P1 :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  o  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   0  |  x  |  2  |
# ------------------
#   3  |  4  |  o  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   0  |  x  |  2  |
# ------------------
#   3  |  4  |  o  |
# ------------------
#   6  |  7  |  x  |
# ------------------
#
#
# P2 :
#
#   0  |  x  |  2  |
# ------------------
#   x  |  4  |  o  |
# ------------------
#   6  |  7  |  x  |
# ------------------
#
#
# P1 :
#
#   0  |  x  |  2  |
# ------------------
#   x  |  4  |  o  |
# ------------------
#   o  |  7  |  x  |
# ------------------
#
#
# P2 :
#
#   o  |  x  |  2  |
# ------------------
#   x  |  4  |  o  |
# ------------------
#   o  |  7  |  x  |
# ------------------
#
#
# P1 :
#
#   o  |  x  |  2  |
# ------------------
#   x  |  4  |  o  |
# ------------------
#   o  |  o  |  x  |
# ------------------
#
#
# P2 :
#
#   o  |  x  |  x  |
# ------------------
#   x  |  4  |  o  |
# ------------------
#   o  |  o  |  x  |
# ------------------
#
#
# P1 :
#
#   o  |  x  |  x  |
# ------------------
#   x  |  x  |  o  |
# ------------------
#   o  |  o  |  x  |
# ------------------
#
# Draw!
# Game 10 Result : Draw
#
# P1 :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  x  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  x  |  x  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
# P2 Wins!
# Game 11 Result : P2
#
# P1 :
#
#   0  |  1  |  2  |
# ------------------
#   x  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   0  |  1  |  x  |
# ------------------
#   x  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  x  |
# ------------------
#   x  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  x  |  x  |
# ------------------
#   x  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P2 Wins!
# Game 12 Result : P2
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  o  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  x  |  o  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  x  |  o  |
# ------------------
#   3  |  4  |  x  |
# ------------------
#   x  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  x  |  o  |
# ------------------
#   x  |  4  |  x  |
# ------------------
#   x  |  7  |  8  |
# ------------------
#
# P2 Wins!
# Game 13 Result : P2
#
# P1 :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  o  |  8  |
# ------------------
#
#
# P2 :
#
#   0  |  x  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  o  |  8  |
# ------------------
#
#
# P1 :
#
#   0  |  x  |  2  |
# ------------------
#   o  |  4  |  5  |
# ------------------
#   6  |  o  |  8  |
# ------------------
#
#
# P2 :
#
#   0  |  x  |  2  |
# ------------------
#   o  |  4  |  x  |
# ------------------
#   6  |  o  |  8  |
# ------------------
#
#
# P1 :
#
#   0  |  x  |  2  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   6  |  o  |  8  |
# ------------------
#
#
# P2 :
#
#   0  |  x  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   6  |  o  |  8  |
# ------------------
#
#
# P1 :
#
#   0  |  x  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   6  |  o  |  o  |
# ------------------
#
#
# P2 :
#
#   0  |  x  |  o  |
# ------------------
#   o  |  x  |  x  |
# ------------------
#   o  |  o  |  o  |
# ------------------
#
# P2 Wins!
# Game 14 Result : P2
#
# P1 :
#
#   0  |  1  |  2  |
# ------------------
#   o  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   o  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  x  |
# ------------------
#   o  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   x  |  x  |  x  |
# ------------------
#   o  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P2 Wins!
# Game 15 Result : P2
#
# P1 :
#
#   0  |  1  |  x  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   0  |  1  |  x  |
# ------------------
#   x  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   0  |  1  |  x  |
# ------------------
#   x  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   0  |  1  |  x  |
# ------------------
#   x  |  x  |  x  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P2 Wins!
# Game 16 Result : P2
#
# P1 :
#
#   0  |  1  |  x  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   0  |  1  |  x  |
# ------------------
#   x  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   o  |  1  |  x  |
# ------------------
#   x  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   o  |  x  |  x  |
# ------------------
#   x  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   o  |  x  |  x  |
# ------------------
#   x  |  4  |  5  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   o  |  x  |  x  |
# ------------------
#   x  |  x  |  5  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
# P2 Wins!
# Game 17 Result : P2
#
# P1 :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  o  |  8  |
# ------------------
#
#
# P2 :
#
#   0  |  x  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  o  |  8  |
# ------------------
#
#
# P1 :
#
#   0  |  x  |  2  |
# ------------------
#   3  |  4  |  o  |
# ------------------
#   6  |  o  |  8  |
# ------------------
#
#
# P2 :
#
#   0  |  x  |  2  |
# ------------------
#   x  |  4  |  o  |
# ------------------
#   6  |  o  |  8  |
# ------------------
#
#
# P1 :
#
#   0  |  x  |  o  |
# ------------------
#   x  |  4  |  o  |
# ------------------
#   6  |  o  |  8  |
# ------------------
#
#
# P2 :
#
#   0  |  x  |  o  |
# ------------------
#   x  |  4  |  o  |
# ------------------
#   6  |  o  |  o  |
# ------------------
#
# P2 Wins!
# Game 18 Result : P2
#
# P1 :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  o  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  o  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  o  |  5  |
# ------------------
#   6  |  7  |  o  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  o  |  x  |
# ------------------
#   6  |  7  |  o  |
# ------------------
#
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  o  |  x  |
# ------------------
#   x  |  7  |  o  |
# ------------------
#
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   x  |  o  |  x  |
# ------------------
#   x  |  7  |  o  |
# ------------------
#
# P2 Wins!
# Game 19 Result : P2
#
# P1 :
#
#   0  |  1  |  x  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   0  |  1  |  x  |
# ------------------
#   x  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P1 :
#
#   0  |  1  |  x  |
# ------------------
#   x  |  o  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
#
# P2 :
#
#   0  |  1  |  x  |
# ------------------
#   x  |  o  |  5  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P1 :
#
#   o  |  1  |  x  |
# ------------------
#   x  |  o  |  5  |
# ------------------
#   6  |  x  |  8  |
# ------------------
#
#
# P2 :
#
#   o  |  1  |  x  |
# ------------------
#   x  |  o  |  5  |
# ------------------
#   6  |  x  |  o  |
# ------------------
#
# P2 Wins!
# Game 20 Result : P2

# %%
print ( " P1=RANDOM VS P2=OPTIMAL OUTPUT" )
print ( " Games P1 won= {}" .format(p1_won))
print ( " Games P2 won= {}" .format(p2_won))
print ( " Games Drawn= {}" .format(draw))
# Out:
#  P1=RANDOM VS P2=OPTIMAL OUTPUT
#  Games P1 won= 0
#  Games P2 won= 19
#  Games Drawn= 1

# %% [markdown]
# ## You vs Optimal

# %%
def you_vs_optimal(middle = True):
    global current
    board = [0, 1, 2, 3, 4, 5, 6, 7, 8]
    current = []
    print("You play as Player 1\n")
    show(board, "Board")
    print()
    curr = ["P1", "P2"]
    i = 0
    move_num = 0
    while True:
        level = 0
        if curr[i] == "P1":
            valid_choice = [str(i) for i in range(9) if i in board]
            while True:
                cell = input("Please enter a valid cell (" + ", ".join(valid_choice) + "): ")
                if cell in valid_choice:
                    break
            while True:
                character = input("Please enter a valid character (x, o): ").lower()
                if character in ["x", "o"]:
                    break
            print()
            board[int(cell)] = character
            show(board, curr[i])
        elif curr[i] == "P2":
            minimax(board, "P2", move_num, level, middle)
            show(current[len(current) - 1], "P2")
            board = current[len(current) - 1]
        print()
        if check_all(board, "x") or check_all(board, "o"):
            print(curr[i] + " Wins!")
            return curr[i]
        if check_draw(board):
            print("Draw!")
            return "Draw"
        i = (i + 1) % 2
        move_num += 1



#you_vs_optimal()

# %%
you_vs_optimal()
# Out:
# You play as Player 1
#
# Board :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  4  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# Please enter a valid cell (0, 1, 2, 3, 4, 5, 6, 7, 8): 4
# Please enter a valid character (x, o): X
#
# P1 :
#
#   0  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# P2 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  8  |
# ------------------
#
# Please enter a valid cell (1, 2, 3, 5, 6, 7, 8): 8
# Please enter a valid character (x, o): O
#
# P1 :
#
#   x  |  1  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  o  |
# ------------------
#
# P2 :
#
#   x  |  o  |  2  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  o  |
# ------------------
#
# Please enter a valid cell (2, 3, 5, 6, 7): 2
# Please enter a valid character (x, o): X
#
# P1 :
#
#   x  |  o  |  x  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   6  |  7  |  o  |
# ------------------
#
# P2 :
#
#   x  |  o  |  x  |
# ------------------
#   3  |  x  |  5  |
# ------------------
#   x  |  7  |  o  |
# ------------------
#
# P2 Wins!
# 'P2'
